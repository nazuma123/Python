# %%
print("hello world")
print("my age is 30")
# Out:
# hello world
# my age is 30

# %%
print("zouraij,my age is 01")
# Out:
# zouraij,my age is 01

# %%
print(10+20)
# Out:
# 30

# %%
name="nazuma" #string
age=30
age2=age
price=25.99
print(name)
print(age)
print(price)
print("my name is:",name)
print("my age is :",age2)
print("my price is:",price)
print(type(name))
print(type(age))
print(type(price))
# Out:
# nazuma
# 30
# 25.99
# my name is: nazuma
# my age is : 30
# my price is: 25.99
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
age=30
old=False
a=None
print(type(old))
print(type(a))
# Out:
# <class 'bool'>
# <class 'NoneType'>

# %%
a=10
b=15
sum=a+b
print(sum)
diff=a-b
print(diff)
prod=a*b
print(prod)
# Out:
# 25
# -5
# 150

# %%
num=10

num +=5
print(num)
print("num:",num)
num +=10
# Out:
# 15
# num: 15

# %%
a=40
b=50
print (not True)
print(not False)
print(not (a<b))
val1= True
val2=True
print("and operator:",val1 and val2)
val1= True
val2=True

print("and operator:",val1 and val2)
print("OR operator:",(a==b) and (a<b))
print("OR operator:",(a==b) and (a>b))
# Out:
# False
# True
# False
# and operator: True
# and operator: True
# OR operator: False
# OR operator: False

# %%
a=50
b=30
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a<=b)
print(a>=b)
# Out:
# False
# True
# True
# False
# False
# True

# %%
a=15
if(a%2 == 0):
    print(f"the number {a} is even.")
else:
    print(f"the number {a} is odd.")
# Out:
# the number 15 is odd.

# %%
a=15
if(a%2 == 0):
  print(f"the number {a} is even.")
else:
  print(f"the number {a} is odd.")
  a=15
  if(a%2 ==1):
     print(f"the number {a} is even.")
  else:
    print(f"the number {a} is odd.")
# Out:
# the number 15 is odd.
# the number 15 is even.

# %%
a=5
square=a**2
print(f"the square of{a} is: {square}")
a=5
cube=a**3
print(f"the cube of {a} is: {cube}")
# Out:
# the square of5 is: 25
# the cube of 5 is: 125

# %%
a=15
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a>b)
print(a<b)
print(a<=b)
print(a>=b)
print(a!=b)
print(a==b)
# Out:
# 20
# 10
# 75
# 3.0
# 3
# 0
# True
# False
# False
# True
# True
# False

# %%
import math
dir(math)
len(dir(math))
import statistics
dir(statistics)
len(dir(statistics))
# Out:
# 71

# %%
pow(2,5,5)
# Out:
# 2

# %%
a=567
b=a%10
print(b)
c=a//10
print(c)
d=c%10
print(d)
e=c//10
print(e)
print(b,d,e)
f=str(b)+str(d)+str(e)
print(int(f))
# Out:
# 7
# 56
# 6
# 5
# 7 6 5
# 765

# %%
a=356
b=a%10
print(b)
c=a//10
print(c)
d=c%10
print(d)
e=c//10
print(e)
print(b,d,e)
f=str(b)+str(d)+str(e)
print(int(f))
# Out:
# 6
# 35
# 5
# 3
# 6 5 3
# 653

# %%
a=567
b=a%10
print(b)
c=a//10
print(c)
d=c%10
print(d)
e=c//10
print(e)
print(b,d,e)
f=str(b)+str(d)+str(e)
print(int(f))
# Out:
# 7
# 56
# 6
# 5
# 7 6 5
# 765
