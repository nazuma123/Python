# %%
x = 1.1
y = 1.5
z = -3.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 54e5
y = 21E5
z = -87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 6+8j
y = 9j
z = -3j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x = 2
y = 2.4
z = 3j
a = float(x)
b = int(y)
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 2.0
# 2
# (2+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
x = int(3)
y = int(5.8)
z = int("7")
print(x)
print(y)
print(z)
# Out:
# 3
# 5
# 7

# %%
x = str("s1")
y = str(2)
z = str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a = '156'
b = float(a)
print(b)
# Out:
# 156.0

# %%
# int -> float

a = 22 # save in the Memory
print(a) # calling from Memory
print(type(a)) #calling and checking the data type

b = float(a) # actual conversions happends here
print(b) # calling from memory
print(type(b)) # calling and chekcing the data type
# Out:
# 22
# <class 'int'>
# 22.0
# <class 'float'>

# %%
#int -> float

a = 22.55 # save in the Memory
print(a) # calling from Memory
print(type(a)) #calling and checking the data type

b = str(a) # actual conversions happends here
print(b) # calling from memory
print(type(b)) # calling and chekcing the data type
# Out:
# 22.55
# <class 'float'>
# 22.55
# <class 'str'>

# %%
# float -> str

a = 22.55 # save in the Memory
print(a) # calling from Memory
print(type(a)) #calling and checking the data type

b = str(a) # actual conversions happends here
print(b) # calling from memory
print(type(b)) # calling and chekcing the data type
# Out:
# 22.55
# <class 'float'>
# 22.55
# <class 'str'>

# %%
# str -> int

a = 'data' # Changed from 'Data' to a valid numeric string
print(a)
print(type(a))

b = int(a)
print(b)
print(type(b))
# Out:
# data
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4262242783.py in <cell line: 0>()
#       5 print(type(a))
#       6
# ----> 7 b = int(a)
#       8 print(b)
#       9 print(type(b))
#
# ValueError: invalid literal for int() with base 10: 'data'

# %%
# str -> int

a = 'Data123'
print(a)
print(type(a))

b = int(a)
print(b)
print(type(b))
# Out:
# Data123
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-51394663.py in <cell line: 0>()
#       5 print(type(a))
#       6
# ----> 7 b = int(a)
#       8 print(b)
#       9 print(type(b))
#
# ValueError: invalid literal for int() with base 10: 'Data123'

# %%
 #str -> int

a = '123'
print(a)
print(type(a))

b = int(a)
print(b)
print(type(b))
# Out:
# 123
# <class 'str'>
# 123
# <class 'int'>

# %%
# str -> float

a = 'science'
print(a)
print(type(a))

b = float(a)
print(b)
print(type(b))
# Out:
# science
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1026194004.py in <cell line: 0>()
#       5 print(type(a))
#       6
# ----> 7 b = float(a)
#       8 print(b)
#       9 print(type(b))
#
# ValueError: could not convert string to float: 'science'

# %%
# str -> float

a = 'science123'
print(a)
print(type(a))

b = float(a)
print(b)
print(type(b))
# Out:
# science123
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-549988525.py in <cell line: 0>()
#       5 print(type(a))
#       6
# ----> 7 b = float(a)
#       8 print(b)
#       9 print(type(b))
#
# ValueError: could not convert string to float: 'science123'

# %%
# str -> float

a = '156.99'
print(a)
print(type(a))

b = float(a)
print(b)
print(type(b))
# Out:
# 156.99
# <class 'str'>
# 156.99
# <class 'float'>
