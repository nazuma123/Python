# %% [markdown]
# <a href="https://colab.research.google.com/github/nazuma123/Python/blob/main/Python_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# +,-,*,/,//,%,>,<,>=,<=,!=,=,==,and,or,pow,**

# %%
10 + 20 + 50 + 90
# Out:
# 170

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
10 - 20
# Out:
# -10

# %%
5 * 4
# Out:
# 20

# %%
2 * 5 # multiply
# Out:
# 10

# %%
2 ** 5 # power
# Out:
# 32

# %%
3 ** 3
# Out:
# 27

# %%
13 / 4
# Out:
# 3.25

# %%
13 // 4
# Out:
# 3

# %%
13 % 4
# Out:
# 1

# %%
22 / 5
# Out:
# 4.4

# %%
22 // 5
# Out:
# 4

# %%
22 % 5
# Out:
# 2

# %%
a = 10
print(a)
# Out:
# 10

# %%
10 == 5
# Out:
# False

# %%
10 == 10
# Out:
# True

# %%
10 > 5
# Out:
# True

# %%
10 < 5
# Out:
# False

# %%
10 != 11
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
10 >= 11
# Out:
# False

# %%
22 <= 22
# Out:
# True

# %%
# or

10 > 20 or 10 < 15
# Out:
# True

# %%
10 <= 7 or 10 <= 5
# Out:
# False

# %%
# and

10 >= 15 and 10 <= 22
# Out:
# False

# %%
# and

100 >= 500 and 100 <= 301
# Out:
# False

# %%
# and

100 >= 500 or 100 <= 301
# Out:
# True

# %%
# functions = functions means which is used to execute a given task or designed task
# Built_in_functions = functions means which is used to execute a given task or designed task developed by python community
# Library = it is like a box where we have built_in_functions
            # ex: math library(box) -> only math built_in_functions are available
            # ex: sklearn library (box) -> only machine learning built in functions are available

# %%
import math # opening the box

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
len(dir(math))
# Out:
# 66

# %%
math.factorial(5)
# Out:
# 120

# %%
math.factorial(6)
# Out:
# 720

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
2 ** 5
# Out:
# 32

# %%
pow(2,5)
# Out:
# 32

# %%
pow(2,5,5)
# Out:
# 2

# %%
pow(2,5,5,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-401817854.py in <cell line: 0>()
# ----> 1 pow(2,5,5,10)
#
# TypeError: pow() takes at most 3 arguments (4 given)
