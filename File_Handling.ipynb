# %% [markdown]
# <a href="https://colab.research.google.com/github/nazuma123/Python/blob/main/File_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **File Handling**
#
# `File Handling concept is used to work with different Files (ex: pdf | pptx | txt | word_doc | csv )`
#
# `In File Handling concept -> we have 3 Modes `
#
# - `Mode w -> write Mode `
# - `Mode a -> add Mode (update)`
# - `Mode r -> read Mode `

# %% [markdown]
# **Mode w**
#
# - `Rule 1: If the File is Not there Mode w will create the file and we can add the data into the file `
#
# - `Rule 2: If the File is Available and File is Empty Mode w can write the data into the file `
#
# - `Rule 3: If the File is Available and There is data in the File but if we pass New data Old data will override `

# %%
a = open('sharuk.txt' , 'w') # write Mode

a.write('Data science')

a.close()

# %%
a = open('kiran.txt' , 'w') # write Mode

a.write('GEN AI')

a.close()

# %%
a = open('srinu.txt' , 'w') # write Mode

a.write('GEN AI')

a.close()

# %%
# Mode a

a = open('sharuk.txt' , 'a') # write Mode

a.write('Data science')

a.close()

# %%
a = open('kiran.txt' , 'a') # write Mode

a.write('GEN AI')

a.close()

# %%
a = open('srinu.txt' , 'a') # write Mode

a.write(' GEN AI')

a.close()

# %%
a = open('sharuk.txt','r')

print(a.read())
# Out:
# Data science

# %%
a = open('prem.txt','r')

print(a.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4121189865.py in <cell line: 0>()
# ----> 1 a = open('prem.txt','r')
#       2
#       3 print(a.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prem.txt'

# %%
f = open('india.txt','w')

f.write('we belong to Indian Country')

f.close()

# %%
f = open('india.txt','w')

f.write('we belong to Indian Country')
# Out:
# 27

# %%
with open('india.txt','w') as f:
  f.write('we belong to Indian Country')

# %%
a = open('india.txt','r')

print(a.read())
# Out:
# we belong to Indian Country

# %%
with open('india.txt','r') as a:
  print(a.read())
# Out:
# we belong to Indian Country

# %% [markdown]
# - `dump -> sending the dict into a json file `
# - `load -> read the dict from a Json file `
# - `dumps -> convert dict to str `
# - `loads -> convert str back to dict `

# %%
# JSON = Java Script Object notation

# %%
import json

# %%
fruits = {'apple':100,'Banana':200,'Carrot':300}

with open('kumar.json','w') as f:
  json.dump(fruits,f)

# %%
with open('kumar.json','r') as f:
  result = json.load(f)

print(result)
# Out:
# {'apple': 100, 'Banana': 200, 'Carrot': 300}

# %%
fruits = {'apple':100,'Banana':200,'Carrot':300} # dict
print(fruits)
print(type(fruits))


res = json.dumps(fruits)
print(res)
print(type(res))
# Out:
# {'apple': 100, 'Banana': 200, 'Carrot': 300}
# <class 'dict'>
# {"apple": 100, "Banana": 200, "Carrot": 300}
# <class 'str'>

# %%
fruits = {'apple':100,'Banana':200,'Carrot':300} # dict
print(fruits)
print(type(fruits))


res = json.dumps(fruits) # dict to str
print(res)
print(type(res))


final = json.loads(res) # str to dict
print(final)
print(type(final))
# Out:
# {'apple': 100, 'Banana': 200, 'Carrot': 300}
# <class 'dict'>
# {"apple": 100, "Banana": 200, "Carrot": 300}
# <class 'str'>
# {'apple': 100, 'Banana': 200, 'Carrot': 300}
# <class 'dict'>
